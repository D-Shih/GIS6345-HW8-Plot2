# %%
# HW8, Part 1, Plot 2
# Create a pie chart to show the proportion of acute care hospitals in each 
# region in Massachusetts
# modified from examples at:
# https://pythonhow.com/accessing-dataframe-columns-rows-and-cells/
# https://matplotlib.org/gallery/pie_and_polar_charts/pie_features.html#sphx-glr-gallery-pie-and-polar-charts-pie-features-py
import matplotlib.pyplot as plt
import numpy as np

# %%
hospitalData = pd.read_csv("HOSPITALS_PT.csv")  #type(hospitalData) is pandas.core.frame.DataFrame

# %%
x = hospitalData["CHIAREGION"]   #type(x) is pandas.core.series.Series #len(x) is 75

# %%
# use dictionary counter method from Think Python Chapter 11
regions = dict()
for i in x:
    regions[i]= regions.get(i,0) + 1         # len(regions) is 8
    
regionPercents = dict()
for i in regions:
    regionPercents[i] = (regions[i]/len(x))*100
    

# Pie chart
labels = []
sizes = []
for i in regionPercents:
    labels.append(i)
    sizes.append(regionPercents[i])

explode = (0,0,0,0,.3,0,0,0)

fig1, ax1 = plt.subplots()
ax1.set_title("Proportion of Acute Care Hosptials by Region")
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle = 60)
        
ax1.axis('equal')  #Equal aspect ratio ensures that pie is drawn as a circle

plt.show()
